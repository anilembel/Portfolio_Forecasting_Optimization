# %% [markdown]
# ## IMPORTS

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates
# %matplotlib inline
from datetime import datetime

# importing yahoo finance for scraping data 
import yfinance as yf

# %% [markdown]
# ## Scraping Data

# %%
# I want to get data on the football clubs Borussia Dortmund, Real Madrid, Galatasaray and Juventus
symbols = ['BVB.DE', 'AJAX.AS', 'OLG.PA', 'JUVE.MI']

#  I used yahoo finance to get the data
start_date = '2018-01-01'
end_date = datetime.today().strftime('%Y-%m-%d')

data = yf.download(symbols, start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1335 entries, 2018-01-02 to 2023-03-14
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   (Adj Close, AJAX.AS)  1334 non-null   float64
#  1   (Adj Close, BVB.DE)   1321 non-null   float64
#  2   (Adj Close, JUVE.MI)  1323 non-null   float64
#  3   (Adj Close, OLG.PA)   1335 non-null   float64
#  4   (Close, AJAX.AS)      1334 non-null   float64
#  5   (Close, BVB.DE)       1321 non-null   float64
#  6   (Close, JUVE.MI)      1323 non-null   float64
#  7   (Close, OLG.PA)       1335 non-null   float64
#  8   (High, AJAX.AS)       1334 non-null   float64
#  9   (High, BVB.DE)        1321 non-null   float64
#  10  (High, JUVE.MI)       1323 non-null   float64
#  11  (High, OLG.PA)        1335 non-null   float64
#  12  (Low, AJAX.AS)        1334 non-null   float64
#  13  (Low, BVB.DE)         1321 non-null   float64
# ...

# %%
data.head()
# Out:
#            Adj Close                              Close                   \
#              AJAX.AS    BVB.DE   JUVE.MI OLG.PA AJAX.AS BVB.DE   JUVE.MI
# Date
# 2018-01-02  9.781010  6.036167  0.696697   2.82    9.90  6.120  0.696697
# 2018-01-03  9.741490  5.962194  0.706367   2.82    9.86  6.045  0.706367
# 2018-01-04  9.800770  6.021372  0.710051   2.79    9.92  6.105  0.710051
# 2018-01-05  9.929207  6.036167  0.713274   2.80   10.05  6.120  0.713274
# 2018-01-08  9.879807  6.164386  0.751494   2.79   10.00  6.250  0.751494
#
#                      High         ...       Low           Open         \
#            OLG.PA AJAX.AS BVB.DE  ...   JUVE.MI OLG.PA AJAX.AS BVB.DE
# Date                              ...
# 2018-01-02   2.82   10.20  6.140  ...  0.694395   2.80    10.0  6.140
# 2018-01-03   2.82    9.90  6.140  ...  0.697158   2.80     9.9  6.140
# 2018-01-04   2.79   10.00  6.165  ...  0.705907   2.76     9.8  6.065
# ...

# %%
data
# Out:
#             Adj Close                              Close                   \
#               AJAX.AS    BVB.DE   JUVE.MI OLG.PA AJAX.AS BVB.DE   JUVE.MI
# Date
# 2018-01-02   9.781010  6.036167  0.696697   2.82    9.90  6.120  0.696697
# 2018-01-03   9.741490  5.962194  0.706367   2.82    9.86  6.045  0.706367
# 2018-01-04   9.800770  6.021372  0.710051   2.79    9.92  6.105  0.710051
# 2018-01-05   9.929207  6.036167  0.713274   2.80   10.05  6.120  0.713274
# 2018-01-08   9.879807  6.164386  0.751494   2.79   10.00  6.250  0.751494
# ...               ...       ...       ...    ...     ...    ...       ...
# 2023-03-08  11.400000  4.028000  0.327200   2.97   11.40  4.028  0.327200
# 2023-03-09  11.400000  4.000000  0.330200   2.97   11.40  4.000  0.330200
# 2023-03-10  11.250000  3.934000  0.331000   2.97   11.25  3.934  0.331000
# 2023-03-13  11.350000  3.814000  0.325000   2.97   11.35  3.814  0.325000
# 2023-03-14  11.350000  3.868000  0.323800   2.97   11.35  3.868  0.323800
#
# ...

# %%
data.dropna()
# Out:
#             Adj Close                              Close                   \
#               AJAX.AS    BVB.DE   JUVE.MI OLG.PA AJAX.AS BVB.DE   JUVE.MI
# Date
# 2018-01-02   9.781010  6.036167  0.696697   2.82    9.90  6.120  0.696697
# 2018-01-03   9.741490  5.962194  0.706367   2.82    9.86  6.045  0.706367
# 2018-01-04   9.800770  6.021372  0.710051   2.79    9.92  6.105  0.710051
# 2018-01-05   9.929207  6.036167  0.713274   2.80   10.05  6.120  0.713274
# 2018-01-08   9.879807  6.164386  0.751494   2.79   10.00  6.250  0.751494
# ...               ...       ...       ...    ...     ...    ...       ...
# 2023-03-08  11.400000  4.028000  0.327200   2.97   11.40  4.028  0.327200
# 2023-03-09  11.400000  4.000000  0.330200   2.97   11.40  4.000  0.330200
# 2023-03-10  11.250000  3.934000  0.331000   2.97   11.25  3.934  0.331000
# 2023-03-13  11.350000  3.814000  0.325000   2.97   11.35  3.814  0.325000
# 2023-03-14  11.350000  3.868000  0.323800   2.97   11.35  3.868  0.323800
#
# ...

# %%
df = data['Adj Close']

# %%
df.reset_index()
# Out:
#            Date    AJAX.AS    BVB.DE   JUVE.MI  OLG.PA
# 0    2018-01-02   9.781010  6.036167  0.696697    2.82
# 1    2018-01-03   9.741490  5.962194  0.706367    2.82
# 2    2018-01-04   9.800770  6.021372  0.710051    2.79
# 3    2018-01-05   9.929207  6.036167  0.713274    2.80
# 4    2018-01-08   9.879807  6.164386  0.751494    2.79
# ...         ...        ...       ...       ...     ...
# 1330 2023-03-08  11.400000  4.028000  0.327200    2.97
# 1331 2023-03-09  11.400000  4.000000  0.330200    2.97
# 1332 2023-03-10  11.250000  3.934000  0.331000    2.97
# 1333 2023-03-13  11.350000  3.814000  0.325000    2.97
# 1334 2023-03-14  11.350000  3.868000  0.323800    2.97
#
# [1335 rows x 5 columns]

# %%
df = df.round(2)

# %%
df.setindex('Date', inplace=True)

# %%
df

# %%
df.to_csv('footbalteamstocks.csv')
